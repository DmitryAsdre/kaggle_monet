# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import torchvision
import matplotlib.pyplot as plt
import numpy as np
from time import sleep
import os
from natsort import natsorted
from PIL import Image

from torch.autograd import Variable
from IPython.display import clear_output

# %%
device = 'cuda'

# %%
# !nvidia-smi
# Out:
# Fri Sep 25 23:06:31 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 450.66       CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 106...  Off  | 00000000:01:00.0  On |                  N/A |
# |  0%   57C    P0    28W / 120W |    725MiB /  3016MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1533      G   /usr/lib/xorg/Xorg                 65MiB |
# |    0   N/A  N/A      2098      G   /usr/lib/xorg/Xorg                229MiB |
# |    0   N/A  N/A      2228      G   /usr/bin/gnome-shell              164MiB |
# |    0   N/A  N/A      2794      G   ...AAAAAAAAA= --shared-files      253MiB |
# +-----------------------------------------------------------------------------+

# %%
class DataSetMonet(Dataset):
    def __init__(self, main_dir, transform):
        self.main_dir = main_dir
        self.transform = transform
        all_imgs = os.listdir(main_dir)
        self.total_imgs = natsorted(all_imgs)

    def __len__(self):
        return len(self.total_imgs)

    def __getitem__(self, idx):
        img_loc = os.path.join(self.main_dir, self.total_imgs[idx])
        image = Image.open(img_loc).convert('RGB')
        tensor_image = self.transform(image)
        return tensor_image

# %%
photo_dataset = DataSetMonet('data/photo_jpg/', transform=torchvision.transforms.ToTensor())
photo_dataloader = DataLoader(photo_dataset, batch_size=12, shuffle=False, num_workers=4, drop_last=True)

# %%
plt.figure(figsize=(14, 14))
data = next(iter(photo_dataloader))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.axis('off')
    picture = np.moveaxis(data[i].numpy(), [0, 1, 2], [2, 0, 1])
    plt.imshow(picture)

# %%
monet_dataset = DataSetMonet('data/monet_jpg/', transform=torchvision.transforms.ToTensor())
monet_dataloader = DataLoader(monet_dataset, batch_size=12, shuffle=False, num_workers=4, drop_last=True)

# %%
plt.figure(figsize=(14, 14))
data = next(iter(monet_dataloader))
for i in range(12):
    plt.subplot(3, 4, i + 1)
    plt.axis('off')
    picture = np.moveaxis(data[i].numpy(), [0, 1, 2], [2, 0, 1])
    plt.imshow(picture)

# %%
adfa
